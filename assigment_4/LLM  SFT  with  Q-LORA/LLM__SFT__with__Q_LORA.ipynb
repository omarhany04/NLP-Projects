# %% [markdown]
# #### Install Dependencies

# %%
# !pip install -q "transformers==4.45.2" "trl==0.9.6" -U bitsandbytes accelerate peft datasets wandb
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 3.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 49.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 39.9 MB/s eta 0:00:00

# %% [markdown]
# #### Authenticate Weights & Biases

# %%
import os
import wandb
wandb.login()
# Out:
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /root/.netrc.
# wandb: Currently logged in as: alyadel15555 (alyadel15555-faculty-of-engineering) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# True

# %% [markdown]
# ### train model

# %%
# %cd /
# !python train.py
# Out:
# /
# 2026-05-12 21:11:18.223895: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /root/.netrc.
# wandb: Currently logged in as: alyadel15555 (alyadel15555-faculty-of-engineering) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ Waiting for wandb.init()...
# wandb: ⣽ Waiting for wandb.init()...
# wandb: ⣾ Waiting for wandb.init()...
# wandb: ⣷ setting up run wdlbjc95 (0.5s)
# wandb: ⣯ setting up run wdlbjc95 (0.5s)
# wandb: ⣟ setting up run wdlbjc95 (0.5s)
# wandb: Tracking run with wandb version 0.26.1
# wandb: Run data is saved locally in /wandb/run-20260512_211121-wdlbjc95
# ...

# %% [markdown]
# #### Verify the Saved Model

# %%
if os.path.exists("./sft_qwen_model"):
    print("Success! The SFT model and tokenizer were saved successfully.")
    print(os.listdir("./sft_qwen_model"))
else:
    print("Model directory not found. Check the training logs for errors.")
# Out:
# Success! The SFT model and tokenizer were saved successfully.
# ['README.md', 'special_tokens_map.json', 'tokenizer.json', 'vocab.json', 'adapter_model.safetensors', 'added_tokens.json', 'merges.txt', 'adapter_config.json', 'tokenizer_config.json']

# %%
# !zip -r qwen_model_backup.zip ./sft_qwen_model
# Out:
#   adding: sft_qwen_model/ (stored 0%)
#   adding: sft_qwen_model/README.md (deflated 65%)
#   adding: sft_qwen_model/special_tokens_map.json (deflated 46%)
#   adding: sft_qwen_model/tokenizer.json (deflated 81%)
#   adding: sft_qwen_model/vocab.json (deflated 61%)
#   adding: sft_qwen_model/adapter_model.safetensors (deflated 7%)
#   adding: sft_qwen_model/added_tokens.json (deflated 36%)
#   adding: sft_qwen_model/merges.txt (deflated 57%)
#   adding: sft_qwen_model/adapter_config.json (deflated 59%)
#   adding: sft_qwen_model/tokenizer_config.json (deflated 65%)
